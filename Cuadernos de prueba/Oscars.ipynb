# %%
import kagglehub
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
movie= "/Users/juanzubiaga/Desktop/BOOTCAMPDS/1-Local/EDA/J-EDA/movies.csv"
movies = pd.read_csv(movie)

# %%
oscar2="/Users/juanzubiaga/Desktop/BOOTCAMPDS/1-Local/EDA/J-EDA/the_oscar_award.csv"
oscar2=pd.read_csv(oscar2)
oscar2.shape
# Out:
# (10889, 7)

# %%
oscar2['category']=oscar2['category'].replace(['OUTSTANDING PICTURE','OUTSTANDING PRODUCTION','OUTSTANDING MOTION PICTURE','BEST MOTION PICTURE'],'BEST PICTURE')

# %%
os= "/Users/juanzubiaga/Desktop/BOOTCAMPDS/1-Local/EDA/oscars_df.csv"
oscars= pd.read_csv(os)
oscars[oscars['Award']=='Winner']
# Out:
#      Unnamed: 0                            Film Oscar Year  \
# 0             0                           Wings    1927/28
# 3             3             The Broadway Melody    1928/29
# 8             8  All Quiet on the Western Front    1929/30
# 13           13                        Cimarron    1930/31
# 18           18                     Grand Hotel    1931/32
# ..          ...                             ...        ...
# 520         520                       Spotlight       2015
# 528         528                       Moonlight       2016
# 537         537              The Shape of Water       2017
# 546         546                      Green Book       2018
# 554         554                        Parasite       2019
#
#                                Film Studio/Producer(s)   Award  \
# 0                                 Famous Players-Lasky  Winner
# 3                                  Metro-Goldwyn-Mayer  Winner
# 8                                            Universal  Winner
# 13                                           RKO Radio  Winner
# 18                                 Metro-Goldwyn-Mayer  Winner
# ..                                                 ...     ...
# 520  Blye Pagon Faust, Steve Golin, Nicole Rocklin,...  Winner
# 528   Adele Romanski, Dede Gardner, and Jeremy Kleiner  Winner
# 537               Guillermo del Toro and J. Miles Dale  Winner
# 546  Jim Burke, Charles B. Wessler, Brian Currie, P...  Winner
# 554                       Kwak Sin-ae and Bong Joon-ho  Winner
#
#      Year of Release  Movie Time              Movie Genre  IMDB Rating  \
# 0               1927         144        Drama,Romance,War          7.5
# 3               1929         100    Drama,Musical,Romance          5.7
# 8               1930         152                Drama,War          8.1
# 13              1931         123            Drama,Western          5.9
# 18              1932         112            Drama,Romance          7.4
# ..               ...         ...                      ...          ...
# 520             2015         129    Biography,Crime,Drama          8.1
# 528             2016         111                    Drama          7.4
# 537             2017         123  Adventure,Drama,Fantasy          7.3
# 546             2018         130   Biography,Comedy,Drama          8.2
# 554             2019         132    Comedy,Drama,Thriller          8.6
#
#     IMDB Votes  ... Tomatometer Status Tomatometer Rating Tomatometer Count  \
# 0       12,221  ...    Certified-Fresh               93.0              46.0
# 3        6,890  ...             Rotten               33.0              24.0
# 8       59,214  ...                NaN                NaN               NaN
# 13       5,851  ...             Rotten               50.0              24.0
# 18      18,314  ...    Certified-Fresh               86.0              42.0
# ..         ...  ...                ...                ...               ...
# 520    440,413  ...    Certified-Fresh               97.0             367.0
# 528    287,563  ...    Certified-Fresh               98.0             384.0
# 537    391,523  ...    Certified-Fresh               92.0             448.0
# 546    422,669  ...    Certified-Fresh               77.0             354.0
# 554    651,517  ...                NaN                NaN               NaN
#
#     Audience Status Audience Rating Audience Count  \
# 0           Upright            78.0         3530.0
# 3           Spilled            21.0         1813.0
# 8               NaN             NaN            NaN
# 13          Spilled            25.0         1514.0
# 18          Upright            77.0         7014.0
# ..              ...             ...            ...
# 520         Upright            93.0        70385.0
# 528         Upright            79.0        45533.0
# 537         Upright            72.0        25784.0
# 546         Upright            91.0        10093.0
# 554             NaN             NaN            NaN
#
#     Tomatometer Top Critics Count Tomatometer Fresh Critics Count  \
# 0                             9.0                            43.0
# 3                             7.0                             8.0
# 8                             NaN                             NaN
# 13                            6.0                            12.0
# 18                           10.0                            36.0
# ..                            ...                             ...
# 520                          59.0                           355.0
# 528                          63.0                           378.0
# 537                          59.0                           414.0
# 546                          49.0                           274.0
# 554                           NaN                             NaN
#
#     Tomatometer Rotten Critics Count                               Film ID
# 0                                3.0  2becf7d5-a3de-46ab-ae45-abdd6b588067
# 3                               16.0  de063f3f-2d35-4e1c-8636-6eb4c16bd236
# 8                                NaN  281742f9-3b4e-480d-b704-c8c15de6b721
# 13                              12.0  db2683c0-128e-4b5c-858f-d9f18c2fb9b9
# 18                               6.0  be69f946-6adc-47e4-8491-79d6c033f59d
# ..                               ...                                   ...
# 520                             12.0  e8728900-9b21-4486-8a41-893439f118f3
# 528                              7.0  194103bc-9dbe-4396-ad61-8370f887ce45
# 537                             34.0  05e574cc-0583-419f-9300-257cf0c4d110
# 546                             80.0  4dd226cc-dc68-40e7-a5b3-3b1bfff594f1
# 554                              NaN  db1a7b9b-b141-4816-a78a-1ba660b98dba
#
# [93 rows x 30 columns]

# %%
oscars1=oscars.copy()
oscars1['Movie Genre'] = oscars1['Movie Genre'].apply(lambda x: x.split(',')[0])
oscars1
# Out:
#      Unnamed: 0                        Film Oscar Year  \
# 0             0                       Wings    1927/28
# 1             1                  7th Heaven    1927/28
# 2             2                  The Racket    1927/28
# 3             3         The Broadway Melody    1928/29
# 4             4                       Alibi    1928/29
# ..          ...                         ...        ...
# 566         566                        Mank       2020
# 567         567                      Minari       2020
# 568         568       Promising Young Woman       2020
# 569         569              Sound of Metal       2020
# 570         570  The Trial of the Chicago 7       2020
#
#                                Film Studio/Producer(s)    Award  \
# 0                                 Famous Players-Lasky   Winner
# 1                                                  Fox  Nominee
# 2                                    The Caddo Company  Nominee
# 3                                  Metro-Goldwyn-Mayer   Winner
# 4                                  Feature Productions  Nominee
# ..                                                 ...      ...
# 566      Ceán Chaffin, Eric Roth, and Douglas Urbanski  Nominee
# 567                                       Christina Oh  Nominee
# 568  Ben Browning, Ashley Fox, Emerald Fennell, and...  Nominee
# 569              Bert Hamelinck and Sacha Ben Harroche  Nominee
# 570                    Marc Platt and Stuart M. Besser  Nominee
#
#      Year of Release  Movie Time Movie Genre  IMDB Rating IMDB Votes  ...  \
# 0               1927         144       Drama          7.5     12,221  ...
# 1               1927         110       Drama          7.7      3,439  ...
# 2               1928          84       Crime          6.7      1,257  ...
# 3               1929         100       Drama          5.7      6,890  ...
# 4               1929          91      Action          5.8        765  ...
# ..               ...         ...         ...          ...        ...  ...
# 566             2020         131   Biography          6.9     65,380  ...
# 567             2020         115       Drama          7.5     57,976  ...
# 568             2020         113       Crime          7.5    122,269  ...
# 569             2019         120       Drama          7.8    102,807  ...
# 570             2020         129       Drama          7.8    156,283  ...
#
#     Tomatometer Status Tomatometer Rating Tomatometer Count Audience Status  \
# 0      Certified-Fresh               93.0              46.0         Upright
# 1                  NaN                NaN               NaN             NaN
# 2                  NaN                NaN               NaN             NaN
# 3               Rotten               33.0              24.0         Spilled
# 4                  NaN                NaN               NaN             NaN
# ..                 ...                ...               ...             ...
# 566                NaN                NaN               NaN             NaN
# 567                NaN                NaN               NaN             NaN
# 568                NaN                NaN               NaN             NaN
# 569                NaN                NaN               NaN             NaN
# 570                NaN                NaN               NaN             NaN
#
#     Audience Rating Audience Count Tomatometer Top Critics Count  \
# 0              78.0         3530.0                           9.0
# 1               NaN            NaN                           NaN
# 2               NaN            NaN                           NaN
# 3              21.0         1813.0                           7.0
# 4               NaN            NaN                           NaN
# ..              ...            ...                           ...
# 566             NaN            NaN                           NaN
# 567             NaN            NaN                           NaN
# 568             NaN            NaN                           NaN
# 569             NaN            NaN                           NaN
# 570             NaN            NaN                           NaN
#
#     Tomatometer Fresh Critics Count Tomatometer Rotten Critics Count  \
# 0                              43.0                              3.0
# 1                               NaN                              NaN
# 2                               NaN                              NaN
# 3                               8.0                             16.0
# 4                               NaN                              NaN
# ..                              ...                              ...
# 566                             NaN                              NaN
# 567                             NaN                              NaN
# 568                             NaN                              NaN
# 569                             NaN                              NaN
# 570                             NaN                              NaN
#
#                                   Film ID
# 0    2becf7d5-a3de-46ab-ae45-abdd6b588067
# 1    19ed3295-a878-4fd2-8e60-5cd7b5f93dad
# 2    3111c2d8-0908-4093-8ff3-99c89f2f2f08
# 3    de063f3f-2d35-4e1c-8636-6eb4c16bd236
# 4    609887c2-877c-43a4-b88c-e40e31096a98
# ..                                    ...
# 566  47d4ae4f-e782-4cd9-9508-4a07302b1c1a
# 567  7262b3a8-214d-4205-985c-70e0860f3236
# 568  d64c669b-7a73-496a-bddb-19cb09264371
# 569  647357e9-c067-46bd-aaeb-24d4344ec124
# 570  cecbca48-f19c-43f4-81d2-da130facda95
#
# [571 rows x 30 columns]

# %%
oscarss=oscars.copy()
conteo_nominaciones=oscarss['Movie Genre'].str.split(',').explode().replace({
    'Musical': 'Música',
    'Music':'Música',
    'Film-Noir': 'Crimen',
    'Comedy':'Comedia',
    'Crime':'Crimen',
    'War': 'Acción',
    'Adventure':'Acción',
    'Family':'Familiar',
    'Action':'Acción',
    'Mystery':'Thriller',
    'History':'Historia/Bio',
    'Biography': 'Historia/Bio',
    'Fantasy':'Fantasia',
    'Sport':'Deporte',
    'Horror':'Otros',
    'Animation':'Otros',
    }).value_counts()

# %%
plt.figure(figsize=(12,7))
plt.pie(data=conteo_nominaciones,x=conteo_nominaciones,labels=conteo_nominaciones.values)
plt.title('Nominaciones a Oscar a Mejor Pelicula 1928-2020. \n (570 películas nominadas)')
plt.legend(conteo_nominaciones.index,title='GÉNERO',loc='center left',bbox_to_anchor=(1,0.5))
plt.show()

# %%
woscars=oscars[oscars['Award']=='Winner']
conteo_generosw=woscars['Movie Genre'].str.split(',').explode().replace({
    'Musical': 'Música',
    'Music':'Música',
    'Film-Noir': 'Crimen',
    'Comedy':'Comedia',
    'Crime':'Crimen',
    'War': 'Acción',
    'Adventure':'Acción',
    'Family':'Familiar',
    'Action':'Acción',
    'Mystery':'Thriller',
    'History':'Historia/Bio',
    'Biography': 'Historia/Bio',
    'Fantasy':'Fantasia',
    'Sport':'Deporte',
    }).value_counts()

# %%
plt.figure(figsize=(12,7))
plt.pie(data=conteo_generosw,x=conteo_generosw,labels=conteo_generosw.values)
plt.title('GANADORAS a Oscar a Mejor Película 1928-2020 \n -93 ediciones-',loc='center')
plt.legend(conteo_generosw.index,title='GÉNERO',loc='center left',bbox_to_anchor=(1,0.5))
plt.show()

# %%
woscars1=woscars.copy()
woscars1['Movie Genre']=woscars1['Movie Genre'].apply(lambda x: x.split(',')[0])
conteo_oscargenprincipal=woscars1['Movie Genre'].value_counts()
conteo_oscargenprincipal
# Out:
# Movie Genre
# Drama        41
# Biography    18
# Comedy       13
# Adventure     9
# Crime         9
# Action        3
# Name: count, dtype: int64

# %%
conteo_oscargenprincipal.keys()
# Out:
# Index(['Drama', 'Biography', 'Comedy', 'Adventure', 'Crime', 'Action'], dtype='object', name='Movie Genre')

# %%
plt.figure(figsize=(12,7))
sns.barplot(conteo_oscargenprincipal,color='gold')
plt.ylabel('PREMIOS')
plt.xlabel('GÉNERO PRINCIPAL')
plt.title('Oscar a Mejor Pelicula 1928-2020',loc='center')
plt.show()

# %% [markdown]
# No he encontrado informacion fiable sobre los Premios Goya, por lo que he recopilado manualmente a través de diversas fuentes (principalmente Wikipedia), todas las ganadoras a Mejor Película.

# %%
conteo_goya= pd.Series([1,4,11,26,8,2,2], 
                       index=['Supervivencia', 'Suspense', 'Comedia','Drama', 'Thriller', 'Fantasía','Terror'])

# %%
plt.figure(figsize=(12,7))
sns.barplot(conteo_goya,color='darkgreen')
plt.ylabel('PREMIOS')
plt.xlabel('GÉNERO PRINCIPAL')
plt.title('PREMIOS GOYA A MEJOR PELÍCULA',loc='center')
plt.show()
