# %%
import kagglehub
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## –––––––––––– OBTENCION Y REVISIÓN DE BASES DE DATOS ––––––––––––––

# %%
box1= "https://raw.githubusercontent.com/prasertcbs/basic-dataset/refs/heads/master/boxoffice.csv"

boxoffice= pd.read_csv(box1)
boxoffice
# Out:
#         rank                                 title studio  lifetime_gross  \
# 0          1          Star Wars: The Force Awakens     BV       936662225
# 1          2                                Avatar    Fox       760507625
# 2          3                         Black Panther     BV       700059566
# 3          4                Avengers: Infinity War     BV       678681680
# 4          5                               Titanic   Par.       659363944
# ...      ...                                   ...    ...             ...
# 15738  15739                           Dog Eat Dog    IFC              80
# 15739  15740                        Paranoid Girls    NaN              78
# 15740  15741  Confession of a Child of the Century  Cohen              74
# 15741  15742                            Storage 24  Magn.              72
# 15742  15743                           Zyzzyx Road   Reg.              30
#
#        year
# 0      2015
# 1      2009
# 2      2018
# 3      2018
# 4      1997
# ...     ...
# 15738  2009
# 15739  2015
# 15740  2015
# 15741  2013
# 15742  2006
#
# [15743 rows x 5 columns]

# %%
((boxoffice.isnull())|(boxoffice=="Unknown")).sum()
# Out:
# rank               0
# title              1
# studio            35
# lifetime_gross     0
# year               0
# dtype: int64

# %% [markdown]
# No voy a analizar nada relativo a los estudios y productoras por lo que por ahora no me importan esos NaNs, y menos una cifra tan pequeña.
#
# He revisado el del título y es que la película se llama Unknown!

# %%
movie= "/Users/juanzubiaga/Desktop/BOOTCAMPDS/1-Local/EDA/J-EDA/movies.csv"

movies = pd.read_csv(movie)
movies.shape
# Out:
# (4802, 24)

# %%
movies[movies['popularity']>5].isnull().sum()
# Out:
# index                      0
# budget                     0
# genres                     0
# homepage                2120
# id                         0
# keywords                 102
# original_language          0
# original_title             0
# overview                   0
# popularity                 0
# production_companies       0
# production_countries       0
# release_date               0
# revenue                    0
# runtime                    0
# spoken_languages           0
# status                     0
# tagline                  306
# title                      0
# vote_average               0
# vote_count                 0
# cast                       0
# crew                       0
# director                   0
# dtype: int64

# %% [markdown]
# Teniendo en cuenta que es una base de datos enorme, tiene peliculas de género independiente y producciones caseras que no me interesan en el análisis, por lo que, dentro de aquellas con un minimo de popularidad, no hay vacíos ni errores que me afecten en lo que voy a estudiar.

# %%
movies.drop(columns=['homepage','original_title','keywords','overview','cast','crew','tagline','production_companies','production_countries','spoken_languages'],inplace=True)

# %%
popmovies=movies[movies['popularity']>5]
popmovies.columns
# Out:
# Index(['index', 'budget', 'genres', 'id', 'original_language', 'popularity',
#        'release_date', 'revenue', 'runtime', 'status', 'title', 'vote_average',
#        'vote_count', 'director'],
#       dtype='object')

# %%
popmovies.sort_values('release_date', ascending=False)
# Out:
#       index     budget                    genres      id original_language  \
# 3302   3302    8000000                     Drama  374461                en
# 4719   4720    8500000                     Drama  339408                en
# 2273   2273   20000000                     Drama  184341                en
# 357     357  100000000                     Drama  271969                en
# 3013   3013   65000000  Adventure Family Fantasy  294272                en
# ...     ...        ...                       ...     ...               ...
# 4258   4259    1488423  Fantasy Animation Family     408                en
# 4238   4238          1              Drama Comedy    3082                en
# 4603   4604     325000            Comedy Romance    3078                en
# 3804   3804    3950000      Action Drama History   22301                en
# 2638   2638   92620000     Drama Science Fiction      19                de
#
#       popularity release_date    revenue  runtime    status  \
# 3302    7.828459   2016-09-16          0    104.0  Released
# 4719    9.452808   2016-09-09   15861566    120.0  Released
# 2273    7.444189   2016-08-26          0    105.0  Released
# 357    29.608322   2016-08-17   94061311    125.0  Released
# 3013   31.974359   2016-08-10  143695338    102.0  Released
# ...          ...          ...        ...      ...       ...
# 4258   80.171283   1937-12-20  184925486     83.0  Released
# 4238   28.276480   1936-02-05    8500000     87.0  Released
# 4603   11.871424   1934-02-22    4500000    105.0  Released
# 3804    8.484123   1930-11-15    8000000    127.0  Released
# 2638   32.351527   1927-01-10     650422    153.0  Released
#
#                                 title  vote_average  vote_count  \
# 3302                       Mr. Church           7.0         129
# 4719            The Birth of a Nation           6.5         178
# 2273                   Hands of Stone           6.1         109
# 357                           Ben-Hur           5.3         621
# 3013                    Pete's Dragon           6.2         679
# ...                               ...           ...         ...
# 4258  Snow White and the Seven Dwarfs           6.9        1914
# 4238                     Modern Times           8.1         856
# 4603            It Happened One Night           7.7         275
# 3804                    Hell's Angels           6.1          19
# 2638                       Metropolis           8.0         657
#
#                  director
# 3302      Bruce Beresford
# 4719          Nate Parker
# 2273  Jonathan Jakubowicz
# 357     Timur Bekmambetov
# 3013         David Lowery
# ...                   ...
# 4258           David Hand
# 4238      Charlie Chaplin
# 4603          Frank Capra
# 3804          James Whale
# 2638           Fritz Lang
#
# [3551 rows x 14 columns]

# %%
peliculasrec=popmovies.merge(boxoffice, on='title')
peliculasrec.shape
# Out:
# (3066, 18)

# %%
((peliculasrec.isnull())|(peliculasrec=='Unknown')).sum()
# Out:
# index                0
# budget               0
# genres               0
# id                   0
# original_language    0
# popularity           0
# release_date         0
# revenue              0
# runtime              0
# status               0
# title                1
# vote_average         0
# vote_count           0
# director             0
# rank                 0
# studio               0
# lifetime_gross       0
# year                 0
# dtype: int64

# %% [markdown]
# Dentro de las películas minimamente populares no hay ningun error. El de titulo es porque la pelicula se llama Unknown.

# %%
oscar= "/Users/juanzubiaga/Desktop/BOOTCAMPDS/1-Local/EDA/J-EDA/the_oscar_award.csv"

oscars=pd.read_csv(oscar)
oscars.shape
# Out:
# (10889, 7)

# %%
oscars['year_ceremony'].value_counts()
# Out:
# year_ceremony
# 1943    186
# 1942    183
# 1944    182
# 1945    169
# 1946    160
#        ...
# 1932     45
# 1931     44
# 1930     42
# 1929     38
# 1928     35
# Name: count, Length: 96, dtype: int64

# %%
((oscars.isnull())|(oscars=='Unknown')).sum()
# Out:
# year_film          0
# year_ceremony      0
# ceremony           0
# category           0
# name               5
# film             319
# winner             0
# dtype: int64

# %%
((oscars['category']=='BEST PICTURE')& (oscars['winner']==True)).sum()
# Out:
# np.int64(62)

# %% [markdown]
# Habiendo tan pocos Nans, no entendia porque salen 62 a mejor pelicula y no 96 como las ediciones que incluye el dataset, y he descubierto que el premio a mejor película ha tenido varios nombres diferentes, asi que voy a agrupar todos en un mismo nombre para facilitar el analisis.

# %%
oscars[(oscars['category']=='OUTSTANDING PICTURE')|(oscars['category']=='OUTSTANDING PRODUCTION')|(oscars['category']=='OUTSTANDING MOTION PICTURE')|(oscars['category']=='BEST MOTION PICTURE')|(oscars['category']=='BEST PICTURE')].isnull().sum()
# Out:
# year_film        0
# year_ceremony    0
# ceremony         0
# category         0
# name             0
# film             0
# winner           0
# dtype: int64

# %%
oscars['category']=oscars['category'].replace(['OUTSTANDING PICTURE','OUTSTANDING PRODUCTION','OUTSTANDING MOTION PICTURE','BEST MOTION PICTURE'],'BEST PICTURE')
oscars[(oscars['category']=='BEST PICTURE')&(oscars['winner']==True)]
# Out:
#        year_film  year_ceremony  ceremony      category  \
# 21          1927           1928         1  BEST PICTURE
# 64          1928           1929         2  BEST PICTURE
# 100         1929           1930         3  BEST PICTURE
# 140         1930           1931         4  BEST PICTURE
# 178         1931           1932         5  BEST PICTURE
# ...          ...            ...       ...           ...
# 10350       2019           2020        92  BEST PICTURE
# 10474       2020           2021        93  BEST PICTURE
# 10591       2021           2022        94  BEST PICTURE
# 10718       2022           2023        95  BEST PICTURE
# 10846       2023           2024        96  BEST PICTURE
#
#                                                     name  \
# 21                                Paramount Famous Lasky
# 64                                   Metro-Goldwyn-Mayer
# 100                                            Universal
# 140                                            RKO Radio
# 178                                  Metro-Goldwyn-Mayer
# ...                                                  ...
# 10350            Kwak Sin Ae and Bong Joon Ho, Producers
# 10474  Frances McDormand, Peter Spears, Mollye Asher,...
# 10591  Philippe Rousselet, Fabrice Gianfermi and Patr...
# 10718  Daniel Kwan, Daniel Scheinert and Jonathan Wan...
# 10846  Emma Thomas, Charles Roven and Christopher Nol...
#
#                                     film  winner
# 21                                 Wings    True
# 64                   The Broadway Melody    True
# 100       All Quiet on the Western Front    True
# 140                             Cimarron    True
# 178                          Grand Hotel    True
# ...                                  ...     ...
# 10350                           Parasite    True
# 10474                          Nomadland    True
# 10591                               CODA    True
# 10718  Everything Everywhere All at Once    True
# 10846                        Oppenheimer    True
#
# [96 rows x 7 columns]

# %%
oscarbp=oscars[(oscars['winner']==True)&(oscars['category']=='BEST PICTURE')]

# %%
oscarbp.rename(columns={'film':'title'}, inplace=True)
# Out:
# /var/folders/3z/73lxqgp11kb61sfk787_46800000gn/T/ipykernel_25338/4090656953.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   oscarbp.rename(columns={'film':'title'}, inplace=True)

# %%
movie100= "/Users/juanzubiaga/Desktop/BOOTCAMPDS/1-Local/EDA/J-EDA/100movies322.csv"
movies100= pd.read_csv(movie100)
movies100.shape
# Out:
# (2000, 13)

# %%
movies100.columns
# Out:
# Index(['Title', 'IMDB Rating', 'Year', 'Month', 'Certificate', 'Runtime',
#        'Directors', 'Stars', 'Genre', 'Filming_location', 'Budget', 'Income',
#        'Country_of_origin'],
#       dtype='object')

# %%
movies100.rename(columns={'Title':'title'}, inplace=True)

# %%
popmovies100=popmovies.merge(movies100)
popmovies100.shape
# Out:
# (1081, 26)

# %%
oscarmovies=oscarbp.merge(popmovies, on='title')
oscarmovies
# Out:
#     year_film  year_ceremony  ceremony      category  \
# 0        1934           1935         7  BEST PICTURE
# 1        1939           1940        12  BEST PICTURE
# 2        1940           1941        13  BEST PICTURE
# 3        1941           1942        14  BEST PICTURE
# 4        1943           1944        16  BEST PICTURE
# ..        ...            ...       ...           ...
# 59       2010           2011        83  BEST PICTURE
# 60       2011           2012        84  BEST PICTURE
# 61       2012           2013        85  BEST PICTURE
# 62       2013           2014        86  BEST PICTURE
# 63       2015           2016        88  BEST PICTURE
#
#                                                  name  \
# 0                                            Columbia
# 1                     Selznick International Pictures
# 2                     Selznick International Pictures
# 3                                    20th Century-Fox
# 4                                        Warner Bros.
# ..                                                ...
# 59  Iain Canning, Emile Sherman and Gareth Unwin, ...
# 60                          Thomas Langmann, Producer
# 61  Grant Heslov, Ben Affleck and George Clooney, ...
# 62  Brad Pitt, Dede Gardner, Jeremy Kleiner, Steve...
# 63  Michael Sugar, Steve Golin, Nicole Rocklin and...
#
#                       title  winner  index    budget                  genres  \
# 0     It Happened One Night    True   4604    325000          Comedy Romance
# 1        Gone with the Wind    True   3813   4000000       Drama Romance War
# 2                   Rebecca    True   4281   1288000           Drama Mystery
# 3   How Green Was My Valley    True   4288   1250000                   Drama
# 4                Casablanca    True   4329    878000           Drama Romance
# ..                      ...     ...    ...       ...                     ...
# 59        The King's Speech    True   2517  15000000           Drama History
# 60               The Artist    True   2459  15000000    Drama Comedy Romance
# 61                     Argo    True   1102  44500000          Drama Thriller
# 62         12 Years a Slave    True   2105  20000000           Drama History
# 63                Spotlight    True   2123  20000000  Drama Thriller History
#
#         id original_language  popularity release_date    revenue  runtime  \
# 0     3078                en   11.871424   1934-02-22    4500000    105.0
# 1      770                en   48.982550   1939-12-15  400176459    238.0
# 2      223                en   18.426825   1940-04-12    6000000    130.0
# 3    43266                en    7.700190   1941-10-28    6000000    118.0
# 4      289                en   43.729123   1942-11-26   10462500    102.0
# ..     ...               ...         ...          ...        ...      ...
# 59   45269                en   54.053576   2010-09-06  414211549    118.0
# 60   74643                en   29.943316   2011-05-15  133432856    100.0
# 61   68734                en   62.010560   2012-10-11  232324128    120.0
# 62   76203                en   95.922900   2013-10-18  187000000    134.0
# 63  314365                en   41.503588   2015-11-06   88346473    128.0
#
#       status  vote_average  vote_count             director
# 0   Released           7.7         275          Frank Capra
# 1   Released           7.7         970       Victor Fleming
# 2   Released           7.7         336     Alfred Hitchcock
# 3   Released           6.8          72            John Ford
# 4   Released           7.9        1422       Michael Curtiz
# ..       ...           ...         ...                  ...
# 59  Released           7.6        2752           Tom Hooper
# 60  Released           7.3        1049  Michel Hazanavicius
# 61  Released           7.1        3423          Ben Affleck
# 62  Released           7.9        3674        Steve McQueen
# 63  Released           7.8        2686         Tom McCarthy
#
# [64 rows x 20 columns]

# %%
oscarmoviesaction=oscarmovies
oscarmoviesaction['genres'] = oscarmoviesaction['genres'].apply(lambda x: x.split())
oscarmoviesaction['genres']=oscarmovies['genres'].replace(['War','Crime','Western','Adventure'],'Action')

# %%
movie100= "/Users/juanzubiaga/Desktop/BOOTCAMPDS/1-Local/EDA/J-EDA/100movies322.csv"
movies100= pd.read_csv(movie100)
movies100
# Out:
#                                            Title  IMDB Rating  Year     Month  \
# 0                       Avatar: The Way of Water          7.8  2022  December
# 1                 Guillermo del Toro's Pinocchio          7.6  2022  December
# 2                                   Bullet Train          7.3  2022    August
# 3                      The Banshees of Inisherin          7.8  2022  November
# 4                                          M3gan          6.4  2022  December
# ...                                          ...          ...   ...       ...
# 1995                       A Tale of Two Sisters          7.1  2003      June
# 1996  Lara Croft Tomb Raider: The Cradle of Life          5.5  2003      July
# 1997                                     Gothika          5.8  2003  November
# 1998                   Ong-Bak: The Thai Warrior          7.1  2003  February
# 1999                                  Open Water          5.8  2003    August
#
#      Certificate Runtime                           Directors  \
# 0          PG-13     192                       James Cameron
# 1             PG     117  Guillermo del Toro, Mark Gustafson
# 2              R     127                        David Leitch
# 3              R     114                     Martin McDonagh
# 4          PG-13     102                    Gerard Johnstone
# ...          ...     ...                                 ...
# 1995           R     114                        Jee woon Kim
# 1996       PG-13     117                         Jan de Bont
# 1997           R      98                   Mathieu Kassovitz
# 1998           R     105                     Prachya Pinkaew
# 1999           R      79                        Chris Kentis
#
#                                                   Stars  \
# 0     Sam Worthington, Zoe Saldana, Sigourney Weaver...
# 1     Ewan McGregor, David Bradley, Gregory Mann, Bu...
# 2     Brad Pitt, Joey King, Aaron Taylor Johnson, Br...
# 3     Colin Farrell, Brendan Gleeson, Kerry Condon, ...
# 4     Jenna Davis, Amie Donald, Allison Williams, Vi...
# ...                                                 ...
# 1995  Lim Soo jung, Yum Jung ah, Kim Kap su, Moon Ge...
# 1996  Angelina Jolie, Gerard Butler, Chris Barrie, C...
# 1997  Halle Berry, Pen lope Cruz, Robert Downey Jr ,...
# 1998  Tony Jaa, Phetthai Vongkumlao, Pumwaree Yodkam...
# 1999  Blanchard Ryan, Daniel Travis, Saul Stein, Mic...
#
#                            Genre Filming_location         Budget  \
# 0     Action, Adventure, Fantasy      New Zealand  $350,000,000
# 1       Animation, Drama, Family              USA   $35,000,000
# 2       Action, Comedy, Thriller            Japan   $85,900,000
# 3                  Comedy, Drama          Ireland        Unknown
# 4       Horror, Sci-Fi, Thriller      New Zealand   $12,000,000
# ...                          ...              ...            ...
# 1995      Drama, Horror, Mystery      South Korea        Unknown
# 1996  Action, Adventure, Fantasy           Greece   $95,000,000
# 1997   Horror, Mystery, Thriller           Canada   $40,000,000
# 1998     Action, Crime, Thriller         Thailand        Unknown
# 1999    Adventure, Drama, Horror          Bahamas      $500,000
#
#                Income                                  Country_of_origin
# 0     $2,267,946,983                                       United States
# 1           $108,967                       United States, Mexico, France
# 2       $239,268,602                                Japan, United States
# 3        $19,720,823              Ireland, United Kingdom, United States
# 4       $171,253,910                                       United States
# ...               ...                                                ...
# 1995      $1,062,878                                         South Korea
# 1996    $160,099,222   United States, Germany, Japan, United Kingdom,...
# 1997    $141,591,324                United States, France, Canada, Spain
# 1998     $20,235,426                         Thailand, France, Hong Kong
# 1999     $54,683,487                                       United States
#
# [2000 rows x 13 columns]

# %%
movies100.isnull().sum()
# Out:
# Title                 0
# IMDB Rating           1
# Year                  0
# Month                 0
# Certificate          34
# Runtime               2
# Directors             0
# Stars                 0
# Genre                 0
# Filming_location      0
# Budget                0
# Income                0
# Country_of_origin     0
# dtype: int64

# %%
movies100['Runtime']=pd.to_numeric(movies100['Runtime'], errors='coerce')
duracion_media=movies100.groupby('Year')['Runtime'].mean().reset_index()

# %%
plt.figure(figsize=(8,6))
sns.lineplot(data=duracion_media, x="Year", y="Runtime")
plt.title('Duracion media de las peliculas a lo largo de los años')
plt.ylabel('Duración media en minutos')
plt.xlabel('Año')
plt.xticks(ticks=range(2003,2023,1))
plt.show()
