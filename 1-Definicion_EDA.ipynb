# %% [markdown]
# ![imagen](./img/ejercicios.png)

# %% [markdown]
# # INFORMACIÓN DEL PROYECTO

# %% [markdown]
# # Titulo
# ## ¿Vamos al cine?

# %% [markdown]
# ## TEMA
# Determinar el impacto que tienen el presupuesto de las peliculas y su duracion, en su recaudacion mundial, su popularidad y los premios Oscar que reciben.
#
#
#
# Las peliculas son cada vez mas extensas, y los presupuestos de las grandes productoras son cada vez mayores a medida que van
#
# monopolizando el mercado.  La cuestion pendiente es determinar si estas tendencias favorecen a la industria, o suponen
#
# trabas en su batalla frente al temido streaming.

# %% [markdown]
# # HIPOTESIS PRINCIPAL
# ## A mayor presupuesto / mas se acercan a los 120 minutos, mas dinero recaudan.

# %% [markdown]
# ### SECUNDARIAS
#
# #### Hipotesis_2 = La pandemia supuso un antes y un despues en la asistencia a los cines, y aun existe miedo a las salas..
#
# #### Hipotesis_3 = ¿Llegaremos a una pelicula popular de cuatro horas?
#
# #### Hipotesis_4 = Las diez peliculas mas rentables (presupuesto-recaudacion) de la historia son de Hollywood
#
# #### Hipotesis_5 = Las plataformas de streaming van a terminar con las salas.
#
# #### Hipotesis_6 = Las peliculas de drama ganan mas premios Oscar a mejor película que cualquier otro género, quizas que todos combinados.
#
# #### Hipotesis_7 = Cuanto mas recientes son las peliculas, peor valoradas están (de media).

# %% [markdown]
# ## OBTENCIÓN DE LOS DATOS

# %% [markdown]
# ### DATASETS Y FUENTES ALTERNATIVAS DE DATOS

# %% [markdown]
# Incluye aquí una vista del dataset o datasets de los que partirás para poder evaluar tu hipótesis. <br>
# También incluye el origen de estos datos y su fuente.

# %%
import pandas as pd
url1= "https://raw.githubusercontent.com/prasertcbs/basic-dataset/refs/heads/master/boxoffice.csv"
boxoffice= pd.read_csv(url1)

# guarda en variables los datasets y su fuente
df_1 = pd.DataFrame()
fuente_1 = "boxoffice.csv obtenido de Github"
# fuente_2 = ""
# df_3 = pd.DataFrame()
# fuente_3 = ""
# df_4 = pd.DataFrame()
# fuente_4 = ""
# df_5 = pd.DataFrame()
# fuente_5 = ""
# ...

# %% [markdown]
# Muestra mediante un head() los principales datasets con los que vas a trabajar

# %%
ruta= "/Users/juanzubiaga/Desktop/BOOTCAMPDS/1-Local/EDA/J-EDA/boxoffice.csv"

boxoffice= pd.read_csv(ruta)
boxoffice.head()
# Out:
#    rank                         title studio  lifetime_gross  year
# 0     1  Star Wars: The Force Awakens     BV       936662225  2015
# 1     2                        Avatar    Fox       760507625  2009
# 2     3                 Black Panther     BV       700059566  2018
# 3     4        Avengers: Infinity War     BV       678681680  2018
# 4     5                       Titanic   Par.       659363944  1997

# %%
ruta= "/Users/juanzubiaga/Desktop/BOOTCAMPDS/1-Local/EDA/J-EDA/AllTime_BO.csv"

tiposbox= pd.read_csv(ruta)
tiposbox.head()
# Out:
#    Rank  Year                                 Movie WorldwideBox Office  \
# 0     1  2009                                Avatar      $2,845,899,541
# 1     2  2019                     Avengers: Endgame      $2,797,800,564
# 2     3  1997                               Titanic      $2,207,986,545
# 3     4  2015  Star Wars Ep. VII: The Force Awakens      $2,064,615,817
# 4     5  2018                Avengers: Infinity War      $2,044,540,523
#
#   DomesticBox Office InternationalBox Office
# 0       $760,507,625          $2,085,391,916
# 1       $858,373,000          $1,939,427,564
# 2       $659,363,944          $1,548,622,601
# 3       $936,662,225          $1,127,953,592
# 4       $678,815,482          $1,365,725,041

# %%
pathinfo= "/Users/juanzubiaga/Desktop/BOOTCAMPDS/1-Local/EDA/J-EDA/movies.csv"

info= pd.read_csv(pathinfo)
info[['budget','original_title','revenue','runtime','vote_average']]
info[info['budget']>250000000]
# Out:
#     index     budget                                    genres  \
# 1       1  300000000                  Adventure Fantasy Action
# 4       4  260000000          Action Adventure Science Fiction
# 5       5  258000000                  Fantasy Action Adventure
# 6       6  260000000                          Animation Family
# 7       7  280000000          Action Adventure Science Fiction
# 10     10  270000000  Adventure Fantasy Action Science Fiction
# 13     13  255000000                  Action Adventure Western
# 17     17  380000000                  Adventure Action Fantasy
#
#                                              homepage     id  \
# 1        http://disney.go.com/disneypictures/pirates/    285
# 4                http://movies.disney.com/john-carter  49529
# 5     http://www.sonypictures.com/movies/spider-man3/    559
# 6        http://disney.go.com/disneypictures/tangled/  38757
# 7   http://marvel.com/movies/movie/193/avengers_ag...  99861
# ...

# %%
pathoscar= "/Users/juanzubiaga/Desktop/BOOTCAMPDS/1-Local/EDA/J-EDA/the_oscar_award.csv"

oscars=pd.read_csv(pathoscar)
oscars[(oscars['winner']==True)&(oscars['category']=="BEST PICTURE")].loc[:,"category":"film"]
# Out:
#            category                                               name  \
# 3923   BEST PICTURE                              Sam Spiegel, Producer
# 4049   BEST PICTURE                          Tony Richardson, Producer
# 4173   BEST PICTURE                           Jack L. Warner, Producer
# 4295   BEST PICTURE                              Robert Wise, Producer
# 4418   BEST PICTURE                           Fred Zinnemann, Producer
# ...             ...                                                ...
# 10350  BEST PICTURE            Kwak Sin Ae and Bong Joon Ho, Producers
# 10474  BEST PICTURE  Frances McDormand, Peter Spears, Mollye Asher,...
# 10591  BEST PICTURE  Philippe Rousselet, Fabrice Gianfermi and Patr...
# 10718  BEST PICTURE  Daniel Kwan, Daniel Scheinert and Jonathan Wan...
# 10846  BEST PICTURE  Emma Thomas, Charles Roven and Christopher Nol...
#
#                                     film
# 3923                  Lawrence of Arabia
# ...
